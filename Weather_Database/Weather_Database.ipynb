# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests
from citipy import citipy
from config import challenge_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 781

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + challenge_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 2 of Set 1 | sao joao da barra
# Processing Record 3 of Set 1 | havre-saint-pierre
# Processing Record 4 of Set 1 | muros
# Processing Record 5 of Set 1 | atuona
# Processing Record 6 of Set 1 | bluff
# Processing Record 7 of Set 1 | castro
# Processing Record 8 of Set 1 | bilma
# Processing Record 9 of Set 1 | clonakilty
# Processing Record 10 of Set 1 | waingapu
# Processing Record 11 of Set 1 | punta arenas
# Processing Record 12 of Set 1 | flin flon
# Processing Record 13 of Set 1 | phan thiet
# Processing Record 14 of Set 1 | maua
# Processing Record 15 of Set 1 | arraial do cabo
# Processing Record 16 of Set 1 | cascais
# Processing Record 17 of Set 1 | nueve de julio
# Processing Record 18 of Set 1 | kruisfontein
# Processing Record 19 of Set 1 | chifeng
# Processing Record 20 of Set 1 | saint george
# Processing Record 21 of Set 1 | sandovo
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | neyshabur
# Processing Record 24 of Set 1 | ginir
# Processing Record 25 of Set 1 | kidal
# Processing Record 26 of Set 1 | kismayo
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 1 | port harcourt
# Processing Record 30 of Set 1 | ardistan
# City not found. Skipping...
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | rikitea
# Processing Record 33 of Set 1 | uthal
# Processing Record 34 of Set 1 | lata
# Processing Record 35 of Set 1 | ushuaia
# Processing Record 36 of Set 1 | qaanaaq
# Processing Record 37 of Set 1 | rochegda
# Processing Record 38 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 39 of Set 1 | kapaa
# Processing Record 40 of Set 1 | east london
# Processing Record 41 of Set 1 | bud
# Processing Record 42 of Set 1 | ilulissat
# Processing Record 43 of Set 1 | puerto escondido
# Processing Record 44 of Set 1 | pangody
# Processing Record 45 of Set 1 | hobart
# Processing Record 46 of Set 1 | fortuna
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | elban
# Processing Record 49 of Set 1 | aklavik
# Processing Record 50 of Set 1 | vigia
# Processing Record 1 of Set 2 | harper
# Processing Record 2 of Set 2 | alyangula
# Processing Record 3 of Set 2 | axim
# Processing Record 4 of Set 2 | jamestown
# Processing Record 5 of Set 2 | sumbawanga
# Processing Record 6 of Set 2 | lazaro cardenas
# Processing Record 7 of Set 2 | codrington
# Processing Record 8 of Set 2 | marcona
# City not found. Skipping...
# Processing Record 9 of Set 2 | bambous virieux
# Processing Record 10 of Set 2 | the pas
# Processing Record 11 of Set 2 | mahibadhoo
# Processing Record 12 of Set 2 | sur
# Processing Record 13 of Set 2 | cap-aux-meules
# Processing Record 14 of Set 2 | talpa
# Processing Record 15 of Set 2 | ouesso
# Processing Record 16 of Set 2 | broken hill
# Processing Record 17 of Set 2 | busselton
# Processing Record 18 of Set 2 | barrow
# Processing Record 19 of Set 2 | bengkulu
# Processing Record 20 of Set 2 | hilo
# Processing Record 21 of Set 2 | saint-pierre
# Processing Record 22 of Set 2 | dzhusaly
# City not found. Skipping...
# Processing Record 23 of Set 2 | port alfred
# Processing Record 24 of Set 2 | karang tengah
# Processing Record 25 of Set 2 | san patricio
# Processing Record 26 of Set 2 | urzhum
# Processing Record 27 of Set 2 | new norfolk
# Processing Record 28 of Set 2 | barcelos
# Processing Record 29 of Set 2 | zheleznogorsk
# Processing Record 30 of Set 2 | kemijarvi
# Processing Record 31 of Set 2 | lahaina
# Processing Record 32 of Set 2 | severo-kurilsk
# Processing Record 33 of Set 2 | biltine
# Processing Record 34 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 35 of Set 2 | sambava
# Processing Record 36 of Set 2 | kiomboi
# Processing Record 37 of Set 2 | mrirt
# City not found. Skipping...
# Processing Record 38 of Set 2 | jacareacanga
# Processing Record 39 of Set 2 | albany
# Processing Record 40 of Set 2 | chokurdakh
# Processing Record 41 of Set 2 | victoria
# Processing Record 42 of Set 2 | ternate
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | butaritari
# Processing Record 45 of Set 2 | kloulklubed
# Processing Record 46 of Set 2 | tiksi
# Processing Record 47 of Set 2 | kavaratti
# Processing Record 48 of Set 2 | ban tak
# Processing Record 49 of Set 2 | cidreira
# Processing Record 50 of Set 2 | bandarbeyla
# Processing Record 1 of Set 3 | ponta do sol
# Processing Record 2 of Set 3 | avarua
# Processing Record 3 of Set 3 | tuatapere
# Processing Record 4 of Set 3 | coalinga
# Processing Record 5 of Set 3 | jumla
# Processing Record 6 of Set 3 | broome
# Processing Record 7 of Set 3 | nanortalik
# Processing Record 8 of Set 3 | ler
# Processing Record 9 of Set 3 | general roca
# Processing Record 10 of Set 3 | port lincoln
# Processing Record 11 of Set 3 | acajutla
# Processing Record 12 of Set 3 | kavieng
# Processing Record 13 of Set 3 | buckeye
# Processing Record 14 of Set 3 | rungata
# City not found. Skipping...
# Processing Record 15 of Set 3 | poiares
# Processing Record 16 of Set 3 | porto novo
# Processing Record 17 of Set 3 | hovd
# Processing Record 18 of Set 3 | dunedin
# Processing Record 19 of Set 3 | wheeling
# Processing Record 20 of Set 3 | geraldton
# Processing Record 21 of Set 3 | husavik
# Processing Record 22 of Set 3 | shirokiy
# Processing Record 23 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 3 | fairbanks
# Processing Record 25 of Set 3 | mahebourg
# Processing Record 26 of Set 3 | gardner
# Processing Record 27 of Set 3 | sturgeon bay
# Processing Record 28 of Set 3 | ribas do rio pardo
# Processing Record 29 of Set 3 | katsuura
# Processing Record 30 of Set 3 | amudat
# Processing Record 31 of Set 3 | pierre
# Processing Record 32 of Set 3 | vallenar
# Processing Record 33 of Set 3 | muzhi
# Processing Record 34 of Set 3 | bredasdorp
# Processing Record 35 of Set 3 | chaoyang
# Processing Record 36 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 37 of Set 3 | san cristobal
# Processing Record 38 of Set 3 | puerto del rosario
# Processing Record 39 of Set 3 | malakal
# Processing Record 40 of Set 3 | saint-philippe
# Processing Record 41 of Set 3 | sinnamary
# Processing Record 42 of Set 3 | tasiilaq
# Processing Record 43 of Set 3 | hermanus
# Processing Record 44 of Set 3 | obregon
# Processing Record 45 of Set 3 | chuy
# Processing Record 46 of Set 3 | derbent
# Processing Record 47 of Set 3 | pangkalanbuun
# Processing Record 48 of Set 3 | pisco
# Processing Record 49 of Set 3 | inderborskiy
# City not found. Skipping...
# Processing Record 50 of Set 3 | coffs harbour
# Processing Record 1 of Set 4 | banikoara
# Processing Record 2 of Set 4 | arawa
# Processing Record 3 of Set 4 | port elizabeth
# Processing Record 4 of Set 4 | nantucket
# Processing Record 5 of Set 4 | baboua
# City not found. Skipping...
# Processing Record 6 of Set 4 | pacific grove
# Processing Record 7 of Set 4 | ukiah
# Processing Record 8 of Set 4 | lavrentiya
# Processing Record 9 of Set 4 | chapais
# Processing Record 10 of Set 4 | tarko-sale
# Processing Record 11 of Set 4 | saint anthony
# Processing Record 12 of Set 4 | skelleftea
# Processing Record 13 of Set 4 | na wa
# Processing Record 14 of Set 4 | thompson
# Processing Record 15 of Set 4 | kysyl-syr
# Processing Record 16 of Set 4 | lorengau
# Processing Record 17 of Set 4 | qaqortoq
# Processing Record 18 of Set 4 | anadyr
# Processing Record 19 of Set 4 | juru
# Processing Record 20 of Set 4 | carnarvon
# Processing Record 21 of Set 4 | hasaki
# Processing Record 22 of Set 4 | los llanos de aridane
# Processing Record 23 of Set 4 | carlyle
# Processing Record 24 of Set 4 | rock springs
# Processing Record 25 of Set 4 | kiunga
# Processing Record 26 of Set 4 | torbay
# Processing Record 27 of Set 4 | walvis bay
# Processing Record 28 of Set 4 | sao filipe
# Processing Record 29 of Set 4 | esperance
# Processing Record 30 of Set 4 | narsaq
# Processing Record 31 of Set 4 | cabo san lucas
# Processing Record 32 of Set 4 | the valley
# Processing Record 33 of Set 4 | nikolskoye
# Processing Record 34 of Set 4 | upernavik
# Processing Record 35 of Set 4 | ribeira brava
# Processing Record 36 of Set 4 | dera din panah
# City not found. Skipping...
# Processing Record 37 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 38 of Set 4 | imbituba
# Processing Record 39 of Set 4 | souillac
# Processing Record 40 of Set 4 | sioux lookout
# Processing Record 41 of Set 4 | kununurra
# Processing Record 42 of Set 4 | dayong
# Processing Record 43 of Set 4 | georgetown
# Processing Record 44 of Set 4 | lima
# Processing Record 45 of Set 4 | bethel
# Processing Record 46 of Set 4 | aginskoye
# Processing Record 47 of Set 4 | wagga wagga
# Processing Record 48 of Set 4 | bjelovar
# Processing Record 49 of Set 4 | vanimo
# Processing Record 50 of Set 4 | ondangwa
# Processing Record 1 of Set 5 | severodvinsk
# Processing Record 2 of Set 5 | ust-ishim
# Processing Record 3 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 4 of Set 5 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 5 | saskylakh
# Processing Record 6 of Set 5 | praya
# Processing Record 7 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 5 | nome
# Processing Record 9 of Set 5 | ostrovnoy
# Processing Record 10 of Set 5 | iqaluit
# Processing Record 11 of Set 5 | provideniya
# Processing Record 12 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 5 | coquimbo
# Processing Record 14 of Set 5 | alofi
# Processing Record 15 of Set 5 | palaia fokaia
# Processing Record 16 of Set 5 | colares
# Processing Record 17 of Set 5 | celano
# Processing Record 18 of Set 5 | doume
# Processing Record 19 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 20 of Set 5 | levittown
# Processing Record 21 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 22 of Set 5 | tuy hoa
# Processing Record 23 of Set 5 | bida
# Processing Record 24 of Set 5 | bahraich
# Processing Record 25 of Set 5 | polovinnoye
# Processing Record 26 of Set 5 | pilar
# Processing Record 27 of Set 5 | carballo
# Processing Record 28 of Set 5 | lompoc
# Processing Record 29 of Set 5 | port-gentil
# Processing Record 30 of Set 5 | monterey
# Processing Record 31 of Set 5 | beringovskiy
# Processing Record 32 of Set 5 | namibe
# Processing Record 33 of Set 5 | ulladulla
# Processing Record 34 of Set 5 | svetlogorsk
# Processing Record 35 of Set 5 | san andres
# Processing Record 36 of Set 5 | xining
# Processing Record 37 of Set 5 | sobolevo
# Processing Record 38 of Set 5 | yerbogachen
# Processing Record 39 of Set 5 | rincon
# Processing Record 40 of Set 5 | ntchisi
# Processing Record 41 of Set 5 | vikhorevka
# Processing Record 42 of Set 5 | banjar
# Processing Record 43 of Set 5 | la ronge
# Processing Record 44 of Set 5 | tchibanga
# Processing Record 45 of Set 5 | rehoboth
# Processing Record 46 of Set 5 | luganville
# Processing Record 47 of Set 5 | spencer
# Processing Record 48 of Set 5 | hami
# Processing Record 49 of Set 5 | peniche
# Processing Record 50 of Set 5 | hithadhoo
# Processing Record 1 of Set 6 | sisimiut
# Processing Record 2 of Set 6 | blyth
# Processing Record 3 of Set 6 | pevek
# Processing Record 4 of Set 6 | yilan
# Processing Record 5 of Set 6 | sorland
# Processing Record 6 of Set 6 | arlit
# Processing Record 7 of Set 6 | guerrero negro
# Processing Record 8 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 6 | solvychegodsk
# Processing Record 10 of Set 6 | surt
# Processing Record 11 of Set 6 | bubaque
# Processing Record 12 of Set 6 | shirochanka
# Processing Record 13 of Set 6 | ales
# Processing Record 14 of Set 6 | bumba
# Processing Record 15 of Set 6 | touros
# Processing Record 16 of Set 6 | purace
# City not found. Skipping...
# Processing Record 17 of Set 6 | dongsheng
# Processing Record 18 of Set 6 | hambantota
# Processing Record 19 of Set 6 | benguela
# Processing Record 20 of Set 6 | dakar
# Processing Record 21 of Set 6 | nishihara
# Processing Record 22 of Set 6 | hamilton
# Processing Record 23 of Set 6 | vanavara
# Processing Record 24 of Set 6 | balashov
# Processing Record 25 of Set 6 | seydi
# Processing Record 26 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 6 | namatanai
# Processing Record 28 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 6 | zunyi
# Processing Record 30 of Set 6 | talnakh
# Processing Record 31 of Set 6 | mandalgovi
# Processing Record 32 of Set 6 | taylorville
# Processing Record 33 of Set 6 | oborniki
# Processing Record 34 of Set 6 | behbahan
# Processing Record 35 of Set 6 | stephenville
# Processing Record 36 of Set 6 | egvekinot
# Processing Record 37 of Set 6 | gornji vakuf
# Processing Record 38 of Set 6 | bardiyah
# Processing Record 39 of Set 6 | shangqiu
# Processing Record 40 of Set 6 | cayenne
# Processing Record 41 of Set 6 | sitka
# Processing Record 42 of Set 6 | berlevag
# Processing Record 43 of Set 6 | khatanga
# Processing Record 44 of Set 6 | vulcan
# Processing Record 45 of Set 6 | visavadar
# Processing Record 46 of Set 6 | puerto ayora
# Processing Record 47 of Set 6 | urumqi
# Processing Record 48 of Set 6 | aswan
# Processing Record 49 of Set 6 | barretos
# Processing Record 50 of Set 6 | panaba
# Processing Record 1 of Set 7 | najran
# Processing Record 2 of Set 7 | glendive
# Processing Record 3 of Set 7 | sheksna
# Processing Record 4 of Set 7 | buala
# Processing Record 5 of Set 7 | kodiak
# Processing Record 6 of Set 7 | belyy yar
# Processing Record 7 of Set 7 | solovetskiy
# City not found. Skipping...
# Processing Record 8 of Set 7 | constitucion
# Processing Record 9 of Set 7 | ribeira grande
# Processing Record 10 of Set 7 | rio branco
# Processing Record 11 of Set 7 | ambodifototra
# City not found. Skipping...
# Processing Record 12 of Set 7 | jawhar
# Processing Record 13 of Set 7 | shizunai
# Processing Record 14 of Set 7 | gulshat
# City not found. Skipping...
# Processing Record 15 of Set 7 | santa cruz
# Processing Record 16 of Set 7 | lohja
# Processing Record 17 of Set 7 | yarmouth
# Processing Record 18 of Set 7 | lebu
# Processing Record 19 of Set 7 | ixtapa
# Processing Record 20 of Set 7 | cap malheureux
# Processing Record 21 of Set 7 | kilindoni
# Processing Record 22 of Set 7 | flinders
# Processing Record 23 of Set 7 | pedernales
# Processing Record 24 of Set 7 | menomonie
# Processing Record 25 of Set 7 | itarema
# Processing Record 26 of Set 7 | jaguarao
# Processing Record 27 of Set 7 | wahpeton
# Processing Record 28 of Set 7 | kutum
# Processing Record 29 of Set 7 | honningsvag
# Processing Record 30 of Set 7 | vostok
# Processing Record 31 of Set 7 | fort nelson
# Processing Record 32 of Set 7 | george town
# Processing Record 33 of Set 7 | te anau
# Processing Record 34 of Set 7 | bakchar
# Processing Record 35 of Set 7 | richards bay
# Processing Record 36 of Set 7 | mount isa
# Processing Record 37 of Set 7 | vila franca do campo
# Processing Record 38 of Set 7 | vardo
# Processing Record 39 of Set 7 | mar del plata
# Processing Record 40 of Set 7 | margate
# Processing Record 41 of Set 7 | ankazoabo
# Processing Record 42 of Set 7 | isangel
# Processing Record 43 of Set 7 | luderitz
# Processing Record 44 of Set 7 | rawannawi
# City not found. Skipping...
# Processing Record 45 of Set 7 | kieta
# Processing Record 46 of Set 7 | tual
# Processing Record 47 of Set 7 | vila velha
# Processing Record 48 of Set 7 | dali
# Processing Record 49 of Set 7 | saldanha
# Processing Record 50 of Set 7 | vinh
# Processing Record 1 of Set 8 | de-kastri
# Processing Record 2 of Set 8 | cochrane
# Processing Record 3 of Set 8 | tuktoyaktuk
# Processing Record 4 of Set 8 | port hardy
# Processing Record 5 of Set 8 | ipora
# Processing Record 6 of Set 8 | ancud
# Processing Record 7 of Set 8 | terney
# Processing Record 8 of Set 8 | velikiy novgorod
# Processing Record 9 of Set 8 | chazuta
# Processing Record 10 of Set 8 | san vicente
# Processing Record 11 of Set 8 | tezu
# Processing Record 12 of Set 8 | tarrega
# Processing Record 13 of Set 8 | skibbereen
# Processing Record 14 of Set 8 | naze
# Processing Record 15 of Set 8 | bull savanna
# Processing Record 16 of Set 8 | tessalit
# Processing Record 17 of Set 8 | faya
# Processing Record 18 of Set 8 | nago
# Processing Record 19 of Set 8 | mino
# Processing Record 20 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 21 of Set 8 | kuvandyk
# Processing Record 22 of Set 8 | huarmey
# Processing Record 23 of Set 8 | mocambique
# City not found. Skipping...
# Processing Record 24 of Set 8 | leua
# Processing Record 25 of Set 8 | susaki
# Processing Record 26 of Set 8 | altea
# Processing Record 27 of Set 8 | balta
# Processing Record 28 of Set 8 | jinxiang
# Processing Record 29 of Set 8 | umm kaddadah
# Processing Record 30 of Set 8 | korla
# Processing Record 31 of Set 8 | nampula
# Processing Record 32 of Set 8 | lewistown
# Processing Record 33 of Set 8 | kosh-agach
# Processing Record 34 of Set 8 | kortkeros
# Processing Record 35 of Set 8 | nicoya
# Processing Record 36 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 8 | olafsvik
# Processing Record 38 of Set 8 | camopi
# Processing Record 39 of Set 8 | tambovka
# Processing Record 40 of Set 8 | nizwa
# Processing Record 41 of Set 8 | sao paulo de olivenca
# Processing Record 42 of Set 8 | buqayq
# City not found. Skipping...
# Processing Record 43 of Set 8 | takayama
# Processing Record 44 of Set 8 | poum
# Processing Record 45 of Set 8 | henties bay
# Processing Record 46 of Set 8 | vao
# Processing Record 47 of Set 8 | coleraine
# Processing Record 48 of Set 8 | jiuquan
# Processing Record 49 of Set 8 | kaabong
# Processing Record 50 of Set 8 | buraydah
# Processing Record 1 of Set 9 | krasnoyarsk-66
# City not found. Skipping...
# Processing Record 2 of Set 9 | maloshuyka
# City not found. Skipping...
# Processing Record 3 of Set 9 | tondano
# Processing Record 4 of Set 9 | auki
# Processing Record 5 of Set 9 | kirya
# Processing Record 6 of Set 9 | polson
# Processing Record 7 of Set 9 | ocos
# Processing Record 8 of Set 9 | bangkal
# Processing Record 9 of Set 9 | tura
# Processing Record 10 of Set 9 | dubbo
# Processing Record 11 of Set 9 | roald
# Processing Record 12 of Set 9 | kegayli
# City not found. Skipping...
# Processing Record 13 of Set 9 | felipe carrillo puerto
# Processing Record 14 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 15 of Set 9 | clyde river
# Processing Record 16 of Set 9 | ekhabi
# Processing Record 17 of Set 9 | stromness
# Processing Record 18 of Set 9 | pangnirtung
# Processing Record 19 of Set 9 | pathein
# Processing Record 20 of Set 9 | grand-lahou
# Processing Record 21 of Set 9 | norman wells
# Processing Record 22 of Set 9 | medina
# Processing Record 23 of Set 9 | juneau
# Processing Record 24 of Set 9 | brae
# Processing Record 25 of Set 9 | nadadores
# Processing Record 26 of Set 9 | eureka
# Processing Record 27 of Set 9 | vestmannaeyjar
# Processing Record 28 of Set 9 | barra patuca
# Processing Record 29 of Set 9 | izumo
# Processing Record 30 of Set 9 | tongren
# Processing Record 31 of Set 9 | bonavista
# Processing Record 32 of Set 9 | tautira
# Processing Record 33 of Set 9 | airai
# Processing Record 34 of Set 9 | tadine
# Processing Record 35 of Set 9 | ormara
# Processing Record 36 of Set 9 | shahreza
# Processing Record 37 of Set 9 | andapa
# Processing Record 38 of Set 9 | bandar-e anzali
# Processing Record 39 of Set 9 | abu dhabi
# Processing Record 40 of Set 9 | wasilla
# Processing Record 41 of Set 9 | lakes entrance
# Processing Record 42 of Set 9 | anito
# Processing Record 43 of Set 9 | khandyga
# Processing Record 44 of Set 9 | carutapera
# Processing Record 45 of Set 9 | sistranda
# Processing Record 46 of Set 9 | shingu
# Processing Record 47 of Set 9 | ouro preto do oeste
# Processing Record 48 of Set 9 | mlonggo
# Processing Record 49 of Set 9 | great yarmouth
# Processing Record 50 of Set 9 | leningradskiy
# Processing Record 1 of Set 10 | stornoway
# Processing Record 2 of Set 10 | havelock
# Processing Record 3 of Set 10 | svetlaya
# Processing Record 4 of Set 10 | sengiley
# Processing Record 5 of Set 10 | chernyshevskiy
# Processing Record 6 of Set 10 | ca mau
# Processing Record 7 of Set 10 | noyabrsk
# Processing Record 8 of Set 10 | terrace
# Processing Record 9 of Set 10 | dolbeau
# City not found. Skipping...
# Processing Record 10 of Set 10 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 10 | rio grande
# Processing Record 12 of Set 10 | santa cruz del sur
# Processing Record 13 of Set 10 | pinsk
# Processing Record 14 of Set 10 | botwood
# Processing Record 15 of Set 10 | kabanjahe
# Processing Record 16 of Set 10 | ouadda
# Processing Record 17 of Set 10 | daska
# Processing Record 18 of Set 10 | pandan
# Processing Record 19 of Set 10 | vila
# Processing Record 20 of Set 10 | durango
# Processing Record 21 of Set 10 | moa
# Processing Record 22 of Set 10 | nurota
# Processing Record 23 of Set 10 | olinda
# Processing Record 24 of Set 10 | asfi
# Processing Record 25 of Set 10 | masalli
# Processing Record 26 of Set 10 | hay river
# Processing Record 27 of Set 10 | taunton
# Processing Record 28 of Set 10 | prado
# Processing Record 29 of Set 10 | prudentopolis
# Processing Record 30 of Set 10 | angoche
# Processing Record 31 of Set 10 | tonk
# Processing Record 32 of Set 10 | erenhot
# Processing Record 33 of Set 10 | antofagasta
# Processing Record 34 of Set 10 | port moresby
# Processing Record 35 of Set 10 | tabou
# Processing Record 36 of Set 10 | yichun
# Processing Record 37 of Set 10 | kawalu
# Processing Record 38 of Set 10 | mutsamudu
# City not found. Skipping...
# Processing Record 39 of Set 10 | vilela
# Processing Record 40 of Set 10 | srednekolymsk
# Processing Record 41 of Set 10 | lagoa
# Processing Record 42 of Set 10 | fagnano olona
# Processing Record 43 of Set 10 | borama
# City not found. Skipping...
# Processing Record 44 of Set 10 | laibin
# Processing Record 45 of Set 10 | lebedyn
# Processing Record 46 of Set 10 | karamea
# City not found. Skipping...
# Processing Record 47 of Set 10 | casablanca
# Processing Record 48 of Set 10 | maloy
# Processing Record 49 of Set 10 | bentiu
# Processing Record 50 of Set 10 | zhuhai
# Processing Record 1 of Set 11 | capelinha
# Processing Record 2 of Set 11 | nowa sol
# Processing Record 3 of Set 11 | marawi
# Processing Record 4 of Set 11 | faanui
# Processing Record 5 of Set 11 | maniitsoq
# Processing Record 6 of Set 11 | aflu
# City not found. Skipping...
# Processing Record 7 of Set 11 | almaznyy
# Processing Record 8 of Set 11 | sal rei
# Processing Record 9 of Set 11 | puerto madryn
# Processing Record 10 of Set 11 | khonsa
# Processing Record 11 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 12 of Set 11 | cabedelo
# Processing Record 13 of Set 11 | la crosse
# Processing Record 14 of Set 11 | kangaatsiaq
# Processing Record 15 of Set 11 | mukdahan
# Processing Record 16 of Set 11 | bolungarvik
# City not found. Skipping...
# Processing Record 17 of Set 11 | luanda
# Processing Record 18 of Set 11 | san quintin
# Processing Record 19 of Set 11 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 11 | rawson
# Processing Record 21 of Set 11 | whittlesea
# Processing Record 22 of Set 11 | adrar
# Processing Record 23 of Set 11 | jiblah
# Processing Record 24 of Set 11 | targu bujor
# Processing Record 25 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 11 | zheleznodorozhnyy
# Processing Record 27 of Set 11 | votkinsk
# Processing Record 28 of Set 11 | ngunguru
# Processing Record 29 of Set 11 | mokhsogollokh
# Processing Record 30 of Set 11 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 11 | turochak
# Processing Record 32 of Set 11 | kaitangata
# Processing Record 33 of Set 11 | flagstaff
# Processing Record 34 of Set 11 | denpasar
# Processing Record 35 of Set 11 | tam ky
# Processing Record 36 of Set 11 | bathsheba
# Processing Record 37 of Set 11 | sorong
# Processing Record 38 of Set 11 | aden
# Processing Record 39 of Set 11 | impfondo
# Processing Record 40 of Set 11 | port blair
# Processing Record 41 of Set 11 | paytug
# City not found. Skipping...
# Processing Record 42 of Set 11 | laguna
# Processing Record 43 of Set 11 | pattoki
# Processing Record 44 of Set 11 | narasannapeta
# Processing Record 45 of Set 11 | ghanzi
# Processing Record 46 of Set 11 | nanga eboko
# Processing Record 47 of Set 11 | acarau
# Processing Record 48 of Set 11 | inhambane
# Processing Record 49 of Set 11 | lieksa
# Processing Record 50 of Set 11 | camacha
# Processing Record 1 of Set 12 | doha
# Processing Record 2 of Set 12 | kerteh
# City not found. Skipping...
# Processing Record 3 of Set 12 | san carlos de bariloche
# Processing Record 4 of Set 12 | noumea
# Processing Record 5 of Set 12 | wamba
# Processing Record 6 of Set 12 | bodden town
# Processing Record 7 of Set 12 | douentza
# Processing Record 8 of Set 12 | puerto carreno
# Processing Record 9 of Set 12 | grindavik
# Processing Record 10 of Set 12 | marsaxlokk
# Processing Record 11 of Set 12 | dickinson
# Processing Record 12 of Set 12 | mikkeli
# Processing Record 13 of Set 12 | tombouctou
# Processing Record 14 of Set 12 | siderno
# Processing Record 15 of Set 12 | bur gabo
# City not found. Skipping...
# Processing Record 16 of Set 12 | tamandare
# Processing Record 17 of Set 12 | mongo
# Processing Record 18 of Set 12 | saint-joseph
# Processing Record 19 of Set 12 | tatarani
# Processing Record 20 of Set 12 | vitim
# Processing Record 21 of Set 12 | veraval
# Processing Record 22 of Set 12 | cururupu
# Processing Record 23 of Set 12 | evensk
# Processing Record 24 of Set 12 | longyearbyen
# Processing Record 25 of Set 12 | saurimo
# Processing Record 26 of Set 12 | terenga
# City not found. Skipping...
# Processing Record 27 of Set 12 | klaksvik
# Processing Record 28 of Set 12 | katsiveli
# City not found. Skipping...
# Processing Record 29 of Set 12 | pimenta bueno
# Processing Record 30 of Set 12 | nizip
# Processing Record 31 of Set 12 | green river
# Processing Record 32 of Set 12 | komsomolskiy
# Processing Record 33 of Set 12 | charters towers
# Processing Record 34 of Set 12 | chisinau
# Processing Record 35 of Set 12 | naftah
# City not found. Skipping...
# Processing Record 36 of Set 12 | sabang
# Processing Record 37 of Set 12 | pechenga
# Processing Record 38 of Set 12 | chinhoyi
# Processing Record 39 of Set 12 | muzaffarabad
# Processing Record 40 of Set 12 | jishou
# Processing Record 41 of Set 12 | grafton
# Processing Record 42 of Set 12 | kiruna
# Processing Record 43 of Set 12 | andenes
# Processing Record 44 of Set 12 | khonuu
# City not found. Skipping...
# Processing Record 45 of Set 12 | mudbidri
# Processing Record 46 of Set 12 | palmer
# Processing Record 47 of Set 12 | nola
# Processing Record 48 of Set 12 | karakendzha
# City not found. Skipping...
# Processing Record 49 of Set 12 | taltal
# Processing Record 50 of Set 12 | ambulu
# Processing Record 1 of Set 13 | prigorodnyy
# Processing Record 2 of Set 13 | oistins
# Processing Record 3 of Set 13 | kahului
# Processing Record 4 of Set 13 | kimbe
# Processing Record 5 of Set 13 | hirara
# Processing Record 6 of Set 13 | pyinmana
# Processing Record 7 of Set 13 | taoudenni
# Processing Record 8 of Set 13 | haradok
# Processing Record 9 of Set 13 | itoman
# Processing Record 10 of Set 13 | pabrade
# Processing Record 11 of Set 13 | novobelokatay
# Processing Record 12 of Set 13 | grand gaube
# Processing Record 13 of Set 13 | gat
# Processing Record 14 of Set 13 | yuxia
# Processing Record 15 of Set 13 | campina verde
# Processing Record 16 of Set 13 | khuzhir
# Processing Record 17 of Set 13 | comodoro rivadavia
# Processing Record 18 of Set 13 | alice springs
# Processing Record 19 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 20 of Set 13 | chimbote
# Processing Record 21 of Set 13 | kurskaya
# Processing Record 22 of Set 13 | lodja
# Processing Record 23 of Set 13 | manado
# Processing Record 24 of Set 13 | jinka
# Processing Record 25 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 26 of Set 13 | fukue
# Processing Record 27 of Set 13 | coro
# Processing Record 28 of Set 13 | shache
# Processing Record 29 of Set 13 | gunjur
# Processing Record 30 of Set 13 | kayan
# Processing Record 31 of Set 13 | balikpapan
# Processing Record 32 of Set 13 | kedougou
# Processing Record 33 of Set 13 | howard springs
# Processing Record 34 of Set 13 | lerwick
# Processing Record 35 of Set 13 | ambilobe
# Processing Record 36 of Set 13 | kaeo
# Processing Record 37 of Set 13 | mildura
# Processing Record 38 of Set 13 | diamantino
# Processing Record 39 of Set 13 | normandin
# Processing Record 40 of Set 13 | shakawe
# Processing Record 41 of Set 13 | chaman
# Processing Record 42 of Set 13 | morondava
# Processing Record 43 of Set 13 | sibu
# Processing Record 44 of Set 13 | naryan-mar
# Processing Record 45 of Set 13 | suba
# Processing Record 46 of Set 13 | phayuha khiri
# Processing Record 47 of Set 13 | mogadishu
# Processing Record 48 of Set 13 | la ligua
# Processing Record 49 of Set 13 | podosinovets
# Processing Record 50 of Set 13 | teacapan
# Processing Record 1 of Set 14 | waipawa
# Processing Record 2 of Set 14 | waddan
# Processing Record 3 of Set 14 | pemangkat
# Processing Record 4 of Set 14 | batticaloa
# Processing Record 5 of Set 14 | kanniyakumari
# Processing Record 6 of Set 14 | tawkar
# City not found. Skipping...
# Processing Record 7 of Set 14 | cumbal
# Processing Record 8 of Set 14 | san jose
# Processing Record 9 of Set 14 | meulaboh
# Processing Record 10 of Set 14 | sayyan
# Processing Record 11 of Set 14 | winterswijk
# Processing Record 12 of Set 14 | mayo
# Processing Record 13 of Set 14 | salina cruz
# Processing Record 14 of Set 14 | hokitika
# Processing Record 15 of Set 14 | nouadhibou
# Processing Record 16 of Set 14 | lancaster
# Processing Record 17 of Set 14 | milkovo
# Processing Record 18 of Set 14 | pucallpa
# Processing Record 19 of Set 14 | barbar
# City not found. Skipping...
# Processing Record 20 of Set 14 | nemuro
# Processing Record 21 of Set 14 | anqing
# Processing Record 22 of Set 14 | caravelas
# Processing Record 23 of Set 14 | pervomaysk
# Processing Record 24 of Set 14 | sao francisco do sul
# Processing Record 25 of Set 14 | barahona
# Processing Record 26 of Set 14 | george
# Processing Record 27 of Set 14 | soyo
# Processing Record 28 of Set 14 | phalodi
# Processing Record 29 of Set 14 | fevralsk
# City not found. Skipping...
# Processing Record 30 of Set 14 | arinos
# Processing Record 31 of Set 14 | sangar
# Processing Record 32 of Set 14 | necochea
# Processing Record 33 of Set 14 | shubarshi
# Processing Record 34 of Set 14 | kuching
# Processing Record 35 of Set 14 | tyrma
# Processing Record 36 of Set 14 | christchurch
# Processing Record 37 of Set 14 | severnyy
# Processing Record 38 of Set 14 | cairns
# Processing Record 39 of Set 14 | schongau
# Processing Record 40 of Set 14 | cooma
# Processing Record 41 of Set 14 | port macquarie
# Processing Record 42 of Set 14 | kudahuvadhoo
# Processing Record 43 of Set 14 | hofn
# Processing Record 44 of Set 14 | manggar
# Processing Record 45 of Set 14 | nanakuli
# Processing Record 46 of Set 14 | tigil
# Processing Record 47 of Set 14 | manoel urbano
# Processing Record 48 of Set 14 | sabha
# Processing Record 49 of Set 14 | kurunegala
# Processing Record 50 of Set 14 | adre
# Processing Record 1 of Set 15 | ondorhaan
# City not found. Skipping...
# Processing Record 2 of Set 15 | praia
# Processing Record 3 of Set 15 | mandera
# Processing Record 4 of Set 15 | deputatskiy
# Processing Record 5 of Set 15 | asosa
# Processing Record 6 of Set 15 | timra
# Processing Record 7 of Set 15 | maun
# Processing Record 8 of Set 15 | peterhead
# Processing Record 9 of Set 15 | sadiqabad
# Processing Record 10 of Set 15 | tabiauea
# City not found. Skipping...
# Processing Record 11 of Set 15 | doctor juan leon mallorquin
# Processing Record 12 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 13 of Set 15 | maksatikha
# Processing Record 14 of Set 15 | varhaug
# Processing Record 15 of Set 15 | chauk
# Processing Record 16 of Set 15 | willowmore
# Processing Record 17 of Set 15 | hervey bay
# Processing Record 18 of Set 15 | mbandaka
# Processing Record 19 of Set 15 | plettenberg bay
# Processing Record 20 of Set 15 | lesogorsk
# Processing Record 21 of Set 15 | solnechnyy
# Processing Record 22 of Set 15 | moose factory
# Processing Record 23 of Set 15 | viedma
# Processing Record 24 of Set 15 | westport
# Processing Record 25 of Set 15 | eskil
# Processing Record 26 of Set 15 | rongcheng
# Processing Record 27 of Set 15 | dreux
# Processing Record 28 of Set 15 | kashi
# Processing Record 29 of Set 15 | kamenka
# Processing Record 30 of Set 15 | yulara
# Processing Record 31 of Set 15 | buzmeyin
# Processing Record 32 of Set 15 | basoko
# Processing Record 33 of Set 15 | manta
# Processing Record 34 of Set 15 | omsukchan
# Processing Record 35 of Set 15 | qiongshan
# Processing Record 36 of Set 15 | bolshiye uki
# City not found. Skipping...
# Processing Record 37 of Set 15 | liverpool
# Processing Record 38 of Set 15 | atasu
# Processing Record 39 of Set 15 | biaora
# Processing Record 40 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 41 of Set 15 | pionerskiy
# Processing Record 42 of Set 15 | avera
# Processing Record 43 of Set 15 | gidole
# Processing Record 44 of Set 15 | inhambupe
# Processing Record 45 of Set 15 | pekan
# Processing Record 46 of Set 15 | ossora
# Processing Record 47 of Set 15 | tawau
# Processing Record 48 of Set 15 | sesheke
# Processing Record 49 of Set 15 | mehran
# Processing Record 50 of Set 15 | palermo
# Processing Record 1 of Set 16 | blagodatnoye
# Processing Record 2 of Set 16 | turukhansk
# Processing Record 3 of Set 16 | northfield
# Processing Record 4 of Set 16 | fort saint john
# City not found. Skipping...
# Processing Record 5 of Set 16 | mionica
# Processing Record 6 of Set 16 | atar
# Processing Record 7 of Set 16 | acapulco
# Processing Record 8 of Set 16 | mahmudabad
# Processing Record 9 of Set 16 | balabac
# Processing Record 10 of Set 16 | matay
# Processing Record 11 of Set 16 | zhigansk
# Processing Record 12 of Set 16 | otradinskiy
# City not found. Skipping...
# Processing Record 13 of Set 16 | follonica
# Processing Record 14 of Set 16 | tidore
# City not found. Skipping...
# Processing Record 15 of Set 16 | miyako
# Processing Record 16 of Set 16 | gillette
# Processing Record 17 of Set 16 | gigmoto
# Processing Record 18 of Set 16 | macamic
# Processing Record 19 of Set 16 | narrabri
# Processing Record 20 of Set 16 | merauke
# Processing Record 21 of Set 16 | bonthe
# Processing Record 22 of Set 16 | abnub
# Processing Record 23 of Set 16 | malanje
# Processing Record 24 of Set 16 | sumter
# Processing Record 25 of Set 16 | kurilsk
# Processing Record 26 of Set 16 | nerchinskiy zavod
# Processing Record 27 of Set 16 | kholtoson
# Processing Record 28 of Set 16 | half moon bay
# Processing Record 29 of Set 16 | samalaeulu
# City not found. Skipping...
# Processing Record 30 of Set 16 | kurchum
# Processing Record 31 of Set 16 | cockburn town
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0   Sao Joao Da Barra -21.64  -41.05     74.16        88          37
# 1  Havre-Saint-Pierre  50.23  -63.60     28.40        92          75
# 2               Muros  42.78   -9.06     53.01        90          70
# 3              Atuona  -9.80 -139.03     79.34        72           1
# 4               Bluff -46.60  168.33     60.01        65           6
# 5              Castro -24.79  -50.01     63.59        96          95
# 6               Bilma  18.69   12.92     66.58        27           0
# 7          Clonakilty  51.62   -8.87     51.01       100          75
# 8            Waingapu  -9.66  120.26     88.74        58          42
# 9        Punta Arenas -53.15  -70.92     39.20        86          40
#
#    Wind Speed Country      Current Description
# 0       12.03      BR               light rain
# 1        4.70      CA            broken clouds
# 2        1.01      ES               light rain
# 3       16.02      PF                clear sky
# 4       10.00      NZ                clear sky
# 5        5.95      BR     heavy intensity rain
# 6        5.64      NE                clear sky
# 7        9.17      IE  light intensity drizzle
# 8        5.79      ID         scattered clouds
# 9       16.11      CL         scattered clouds

# %%
# Reorganize column order
new_column_order=['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#                  City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0   Sao Joao Da Barra      BR -21.64  -41.05     74.16        88          37
# 1  Havre-Saint-Pierre      CA  50.23  -63.60     28.40        92          75
# 2               Muros      ES  42.78   -9.06     53.01        90          70
# 3              Atuona      PF  -9.80 -139.03     79.34        72           1
# 4               Bluff      NZ -46.60  168.33     60.01        65           6
# 5              Castro      BR -24.79  -50.01     63.59        96          95
# 6               Bilma      NE  18.69   12.92     66.58        27           0
# 7          Clonakilty      IE  51.62   -8.87     51.01       100          75
# 8            Waingapu      ID  -9.66  120.26     88.74        58          42
# 9        Punta Arenas      CL -53.15  -70.92     39.20        86          40
#
#    Wind Speed      Current Description
# 0       12.03               light rain
# 1        4.70            broken clouds
# 2        1.01               light rain
# 3       16.02                clear sky
# 4       10.00                clear sky
# 5        5.95     heavy intensity rain
# 6        5.64                clear sky
# 7        9.17  light intensity drizzle
# 8        5.79         scattered clouds
# 9       16.11         scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
