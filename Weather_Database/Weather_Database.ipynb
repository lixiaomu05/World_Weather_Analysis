# %%
# Import the dependencies.
import pandas as pd
import numpy as np
import requests
from citipy import citipy
from config import challenge_api_key
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 769

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + challenge_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=7577fccf8ad296f9f647a7f74ead8a3e

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | carnarvon
# Processing Record 2 of Set 1 | kavieng
# Processing Record 3 of Set 1 | ponta do sol
# Processing Record 4 of Set 1 | singaraja
# Processing Record 5 of Set 1 | anadyr
# Processing Record 6 of Set 1 | norman wells
# Processing Record 7 of Set 1 | cururupu
# Processing Record 8 of Set 1 | severo-kurilsk
# Processing Record 9 of Set 1 | hofn
# Processing Record 10 of Set 1 | iqaluit
# Processing Record 11 of Set 1 | fortuna
# Processing Record 12 of Set 1 | butaritari
# Processing Record 13 of Set 1 | atuona
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | kitgum
# Processing Record 16 of Set 1 | upernavik
# Processing Record 17 of Set 1 | yellowknife
# Processing Record 18 of Set 1 | coihaique
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | cockburn town
# Processing Record 21 of Set 1 | mana
# Processing Record 22 of Set 1 | cayenne
# Processing Record 23 of Set 1 | jamestown
# Processing Record 24 of Set 1 | albany
# Processing Record 25 of Set 1 | north platte
# Processing Record 26 of Set 1 | pringsewu
# Processing Record 27 of Set 1 | denpasar
# Processing Record 28 of Set 1 | lavrentiya
# Processing Record 29 of Set 1 | ostrovnoy
# Processing Record 30 of Set 1 | tuktoyaktuk
# Processing Record 31 of Set 1 | karratha
# Processing Record 32 of Set 1 | alofi
# Processing Record 33 of Set 1 | bethel
# Processing Record 34 of Set 1 | mount isa
# Processing Record 35 of Set 1 | mar del plata
# Processing Record 36 of Set 1 | yanam
# Processing Record 37 of Set 1 | mahebourg
# Processing Record 38 of Set 1 | kamyshevatskaya
# Processing Record 39 of Set 1 | ossora
# Processing Record 40 of Set 1 | victoria
# Processing Record 41 of Set 1 | punta arenas
# Processing Record 42 of Set 1 | front royal
# Processing Record 43 of Set 1 | port hardy
# Processing Record 44 of Set 1 | ceres
# Processing Record 45 of Set 1 | new norfolk
# Processing Record 46 of Set 1 | san patricio
# Processing Record 47 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 48 of Set 1 | hermanus
# Processing Record 49 of Set 1 | oksfjord
# Processing Record 50 of Set 1 | asyut
# Processing Record 1 of Set 2 | gomel
# Processing Record 2 of Set 2 | buqayq
# City not found. Skipping...
# Processing Record 3 of Set 2 | nanortalik
# Processing Record 4 of Set 2 | airai
# Processing Record 5 of Set 2 | mataura
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | ratnagiri
# Processing Record 8 of Set 2 | ibiuna
# Processing Record 9 of Set 2 | kaeo
# Processing Record 10 of Set 2 | dunedin
# Processing Record 11 of Set 2 | havoysund
# Processing Record 12 of Set 2 | kavaratti
# Processing Record 13 of Set 2 | havelock
# Processing Record 14 of Set 2 | ambovombe
# Processing Record 15 of Set 2 | nelson bay
# Processing Record 16 of Set 2 | abu samrah
# Processing Record 17 of Set 2 | azangaro
# Processing Record 18 of Set 2 | puerto ayora
# Processing Record 19 of Set 2 | hilo
# Processing Record 20 of Set 2 | riberalta
# Processing Record 21 of Set 2 | dikson
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | bordighera
# Processing Record 25 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 2 | chokurdakh
# Processing Record 27 of Set 2 | saint-philippe
# Processing Record 28 of Set 2 | kingman
# Processing Record 29 of Set 2 | cabo san lucas
# Processing Record 30 of Set 2 | smolensk
# Processing Record 31 of Set 2 | vardo
# Processing Record 32 of Set 2 | vaini
# Processing Record 33 of Set 2 | lata
# Processing Record 34 of Set 2 | castro
# Processing Record 35 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 36 of Set 2 | conde
# Processing Record 37 of Set 2 | ushuaia
# Processing Record 38 of Set 2 | mechoacan
# City not found. Skipping...
# Processing Record 39 of Set 2 | palmer
# Processing Record 40 of Set 2 | scarborough
# Processing Record 41 of Set 2 | mullaitivu
# City not found. Skipping...
# Processing Record 42 of Set 2 | barrow
# Processing Record 43 of Set 2 | busselton
# Processing Record 44 of Set 2 | claremore
# Processing Record 45 of Set 2 | saldanha
# Processing Record 46 of Set 2 | dudinka
# Processing Record 47 of Set 2 | chizhou
# Processing Record 48 of Set 2 | georgetown
# Processing Record 49 of Set 2 | bredasdorp
# Processing Record 50 of Set 2 | marawi
# Processing Record 1 of Set 3 | necochea
# Processing Record 2 of Set 3 | mandali
# Processing Record 3 of Set 3 | diffa
# Processing Record 4 of Set 3 | provideniya
# Processing Record 5 of Set 3 | mehamn
# Processing Record 6 of Set 3 | uhlove
# Processing Record 7 of Set 3 | nome
# Processing Record 8 of Set 3 | isangel
# Processing Record 9 of Set 3 | shelburne
# Processing Record 10 of Set 3 | san jeronimo
# Processing Record 11 of Set 3 | najran
# Processing Record 12 of Set 3 | aldan
# Processing Record 13 of Set 3 | pirapora
# Processing Record 14 of Set 3 | oranjemund
# Processing Record 15 of Set 3 | araouane
# Processing Record 16 of Set 3 | rocha
# Processing Record 17 of Set 3 | fairbanks
# Processing Record 18 of Set 3 | itarema
# Processing Record 19 of Set 3 | aktash
# Processing Record 20 of Set 3 | siauliai
# Processing Record 21 of Set 3 | sao joao da barra
# Processing Record 22 of Set 3 | lasa
# Processing Record 23 of Set 3 | grand forks
# Processing Record 24 of Set 3 | san cristobal
# Processing Record 25 of Set 3 | naze
# Processing Record 26 of Set 3 | mao
# Processing Record 27 of Set 3 | kushmurun
# Processing Record 28 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 29 of Set 3 | bambous virieux
# Processing Record 30 of Set 3 | baykit
# Processing Record 31 of Set 3 | lorengau
# Processing Record 32 of Set 3 | saskylakh
# Processing Record 33 of Set 3 | kapaa
# Processing Record 34 of Set 3 | okhotsk
# Processing Record 35 of Set 3 | marzuq
# Processing Record 36 of Set 3 | khatanga
# Processing Record 37 of Set 3 | gat
# Processing Record 38 of Set 3 | las palmas
# Processing Record 39 of Set 3 | pevek
# Processing Record 40 of Set 3 | vao
# Processing Record 41 of Set 3 | zolotkovo
# Processing Record 42 of Set 3 | port elizabeth
# Processing Record 43 of Set 3 | cape town
# Processing Record 44 of Set 3 | talnakh
# Processing Record 45 of Set 3 | filimonovo
# Processing Record 46 of Set 3 | vanimo
# Processing Record 47 of Set 3 | udachnyy
# Processing Record 48 of Set 3 | price
# Processing Record 49 of Set 3 | bandarbeyla
# Processing Record 50 of Set 3 | anaco
# Processing Record 1 of Set 4 | the valley
# Processing Record 2 of Set 4 | little current
# Processing Record 3 of Set 4 | ponta delgada
# Processing Record 4 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 4 | pingshan
# Processing Record 6 of Set 4 | pisco
# Processing Record 7 of Set 4 | svetlyy
# Processing Record 8 of Set 4 | umm lajj
# Processing Record 9 of Set 4 | shaowu
# Processing Record 10 of Set 4 | narnaund
# Processing Record 11 of Set 4 | khor
# Processing Record 12 of Set 4 | hithadhoo
# Processing Record 13 of Set 4 | zhangjiakou
# Processing Record 14 of Set 4 | porto walter
# Processing Record 15 of Set 4 | nguiu
# City not found. Skipping...
# Processing Record 16 of Set 4 | hamilton
# Processing Record 17 of Set 4 | qaanaaq
# Processing Record 18 of Set 4 | itaituba
# Processing Record 19 of Set 4 | piryion
# City not found. Skipping...
# Processing Record 20 of Set 4 | malakal
# Processing Record 21 of Set 4 | sosnovo-ozerskoye
# Processing Record 22 of Set 4 | keti bandar
# Processing Record 23 of Set 4 | sungaipenuh
# Processing Record 24 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 25 of Set 4 | east london
# Processing Record 26 of Set 4 | wukari
# Processing Record 27 of Set 4 | saint george
# Processing Record 28 of Set 4 | tessalit
# Processing Record 29 of Set 4 | biak
# Processing Record 30 of Set 4 | whitehorse
# Processing Record 31 of Set 4 | maragogi
# Processing Record 32 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 33 of Set 4 | fond du lac
# Processing Record 34 of Set 4 | kruisfontein
# Processing Record 35 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 36 of Set 4 | kalemie
# Processing Record 37 of Set 4 | brasileia
# Processing Record 38 of Set 4 | chokwe
# Processing Record 39 of Set 4 | fevralsk
# City not found. Skipping...
# Processing Record 40 of Set 4 | onega
# Processing Record 41 of Set 4 | narsaq
# Processing Record 42 of Set 4 | clyde river
# Processing Record 43 of Set 4 | salalah
# Processing Record 44 of Set 4 | portland
# Processing Record 45 of Set 4 | palu
# Processing Record 46 of Set 4 | beloha
# Processing Record 47 of Set 4 | codrington
# Processing Record 48 of Set 4 | mantua
# Processing Record 49 of Set 4 | nador
# Processing Record 50 of Set 4 | bolungarvik
# City not found. Skipping...
# Processing Record 1 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 2 of Set 5 | avarua
# Processing Record 3 of Set 5 | talovaya
# Processing Record 4 of Set 5 | arraial do cabo
# Processing Record 5 of Set 5 | otane
# Processing Record 6 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 5 | hervey bay
# Processing Record 8 of Set 5 | souillac
# Processing Record 9 of Set 5 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 5 | ruatoria
# City not found. Skipping...
# Processing Record 11 of Set 5 | port alfred
# Processing Record 12 of Set 5 | meulaboh
# Processing Record 13 of Set 5 | letterkenny
# Processing Record 14 of Set 5 | kahului
# Processing Record 15 of Set 5 | meadow lake
# Processing Record 16 of Set 5 | vila velha
# Processing Record 17 of Set 5 | solovetskiy
# City not found. Skipping...
# Processing Record 18 of Set 5 | ardatov
# Processing Record 19 of Set 5 | nata
# Processing Record 20 of Set 5 | port blair
# Processing Record 21 of Set 5 | kaitangata
# Processing Record 22 of Set 5 | ambulu
# Processing Record 23 of Set 5 | el faiyum
# City not found. Skipping...
# Processing Record 24 of Set 5 | tiksi
# Processing Record 25 of Set 5 | santa rosa
# Processing Record 26 of Set 5 | nikel
# Processing Record 27 of Set 5 | lagoa
# Processing Record 28 of Set 5 | verkhnetulomskiy
# Processing Record 29 of Set 5 | saint-leu
# Processing Record 30 of Set 5 | providencia
# Processing Record 31 of Set 5 | saint quentin
# City not found. Skipping...
# Processing Record 32 of Set 5 | cidreira
# Processing Record 33 of Set 5 | lundazi
# Processing Record 34 of Set 5 | kalmunai
# Processing Record 35 of Set 5 | yining
# Processing Record 36 of Set 5 | puertollano
# Processing Record 37 of Set 5 | thinadhoo
# Processing Record 38 of Set 5 | kurchum
# Processing Record 39 of Set 5 | segou
# Processing Record 40 of Set 5 | evensk
# Processing Record 41 of Set 5 | guerrero negro
# Processing Record 42 of Set 5 | manokwari
# Processing Record 43 of Set 5 | honiara
# Processing Record 44 of Set 5 | berlevag
# Processing Record 45 of Set 5 | pimentel
# Processing Record 46 of Set 5 | chancay
# Processing Record 47 of Set 5 | bardiyah
# Processing Record 48 of Set 5 | praia
# Processing Record 49 of Set 5 | ipora
# Processing Record 50 of Set 5 | oktyabrskiy
# Processing Record 1 of Set 6 | bundaberg
# Processing Record 2 of Set 6 | barranca
# Processing Record 3 of Set 6 | gotsu
# Processing Record 4 of Set 6 | benicarlo
# Processing Record 5 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 6 of Set 6 | christchurch
# Processing Record 7 of Set 6 | torbay
# Processing Record 8 of Set 6 | dutlwe
# Processing Record 9 of Set 6 | mersing
# Processing Record 10 of Set 6 | banda aceh
# Processing Record 11 of Set 6 | phalaborwa
# Processing Record 12 of Set 6 | arganil
# Processing Record 13 of Set 6 | ishikari
# Processing Record 14 of Set 6 | mount gambier
# Processing Record 15 of Set 6 | flin flon
# Processing Record 16 of Set 6 | roma
# Processing Record 17 of Set 6 | maneadero
# Processing Record 18 of Set 6 | derzhavinsk
# Processing Record 19 of Set 6 | orchard homes
# Processing Record 20 of Set 6 | odweyne
# Processing Record 21 of Set 6 | novobureyskiy
# Processing Record 22 of Set 6 | altamont
# Processing Record 23 of Set 6 | nyurba
# Processing Record 24 of Set 6 | menomonie
# Processing Record 25 of Set 6 | skalistyy
# City not found. Skipping...
# Processing Record 26 of Set 6 | sisimiut
# Processing Record 27 of Set 6 | chunskiy
# Processing Record 28 of Set 6 | falealupo
# City not found. Skipping...
# Processing Record 29 of Set 6 | vieste
# Processing Record 30 of Set 6 | cherskiy
# Processing Record 31 of Set 6 | tazovskiy
# Processing Record 32 of Set 6 | corralillo
# Processing Record 33 of Set 6 | kodiak
# Processing Record 34 of Set 6 | loandjili
# Processing Record 35 of Set 6 | jardim
# Processing Record 36 of Set 6 | paamiut
# Processing Record 37 of Set 6 | suez
# Processing Record 38 of Set 6 | golovino
# Processing Record 39 of Set 6 | tasiilaq
# Processing Record 40 of Set 6 | arenapolis
# Processing Record 41 of Set 6 | samusu
# City not found. Skipping...
# Processing Record 42 of Set 6 | caravelas
# Processing Record 43 of Set 6 | vostok
# Processing Record 44 of Set 6 | acarau
# Processing Record 45 of Set 6 | sungairaya
# Processing Record 46 of Set 6 | berbera
# Processing Record 47 of Set 6 | smithers
# Processing Record 48 of Set 6 | labe
# Processing Record 49 of Set 6 | capitan bado
# Processing Record 50 of Set 6 | bacungan
# Processing Record 1 of Set 7 | chadan
# Processing Record 2 of Set 7 | sembakung
# Processing Record 3 of Set 7 | husavik
# Processing Record 4 of Set 7 | luderitz
# Processing Record 5 of Set 7 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 7 of Set 7 | fuxin
# Processing Record 8 of Set 7 | ancud
# Processing Record 9 of Set 7 | panguipulli
# Processing Record 10 of Set 7 | inirida
# Processing Record 11 of Set 7 | santander
# Processing Record 12 of Set 7 | shitkino
# Processing Record 13 of Set 7 | koyilandi
# City not found. Skipping...
# Processing Record 14 of Set 7 | flinders
# Processing Record 15 of Set 7 | varaklani
# City not found. Skipping...
# Processing Record 16 of Set 7 | kununurra
# Processing Record 17 of Set 7 | verkhniy fiagdon
# Processing Record 18 of Set 7 | saint-francois
# Processing Record 19 of Set 7 | hasaki
# Processing Record 20 of Set 7 | moree
# Processing Record 21 of Set 7 | fort-shevchenko
# Processing Record 22 of Set 7 | chateaubelair
# Processing Record 23 of Set 7 | puerto ayacucho
# Processing Record 24 of Set 7 | vila franca do campo
# Processing Record 25 of Set 7 | laguna
# Processing Record 26 of Set 7 | negara
# Processing Record 27 of Set 7 | limbazi
# Processing Record 28 of Set 7 | sao filipe
# Processing Record 29 of Set 7 | kamenka
# Processing Record 30 of Set 7 | faya
# Processing Record 31 of Set 7 | catamarca
# Processing Record 32 of Set 7 | dingle
# Processing Record 33 of Set 7 | ahuimanu
# Processing Record 34 of Set 7 | tokmak
# Processing Record 35 of Set 7 | okha
# Processing Record 36 of Set 7 | ranong
# Processing Record 37 of Set 7 | sorland
# Processing Record 38 of Set 7 | auchterarder
# Processing Record 39 of Set 7 | alice springs
# Processing Record 40 of Set 7 | qaqortoq
# Processing Record 41 of Set 7 | tailai
# Processing Record 42 of Set 7 | takoradi
# Processing Record 43 of Set 7 | saint-denis
# Processing Record 44 of Set 7 | leshan
# Processing Record 45 of Set 7 | dianopolis
# City not found. Skipping...
# Processing Record 46 of Set 7 | margate
# Processing Record 47 of Set 7 | zaysan
# Processing Record 48 of Set 7 | azul
# Processing Record 49 of Set 7 | vestmannaeyjar
# Processing Record 50 of Set 7 | diamantino
# Processing Record 1 of Set 8 | thompson
# Processing Record 2 of Set 8 | gao
# Processing Record 3 of Set 8 | chuy
# Processing Record 4 of Set 8 | chincha alta
# Processing Record 5 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 6 of Set 8 | komsomolskiy
# Processing Record 7 of Set 8 | clinton
# Processing Record 8 of Set 8 | geraldton
# Processing Record 9 of Set 8 | kupang
# Processing Record 10 of Set 8 | sarny
# Processing Record 11 of Set 8 | chicama
# Processing Record 12 of Set 8 | dakar
# Processing Record 13 of Set 8 | lere
# Processing Record 14 of Set 8 | mandera
# Processing Record 15 of Set 8 | inhambane
# Processing Record 16 of Set 8 | nattam
# Processing Record 17 of Set 8 | soldatskaya
# Processing Record 18 of Set 8 | eureka
# Processing Record 19 of Set 8 | mogadishu
# Processing Record 20 of Set 8 | kungurtug
# Processing Record 21 of Set 8 | suba
# Processing Record 22 of Set 8 | champerico
# Processing Record 23 of Set 8 | sioux lookout
# Processing Record 24 of Set 8 | novoagansk
# Processing Record 25 of Set 8 | buraydah
# Processing Record 26 of Set 8 | khandyga
# Processing Record 27 of Set 8 | saint-louis
# Processing Record 28 of Set 8 | hambantota
# Processing Record 29 of Set 8 | pathein
# Processing Record 30 of Set 8 | pokhara
# Processing Record 31 of Set 8 | malaya
# Processing Record 32 of Set 8 | tulum
# Processing Record 33 of Set 8 | forecariah
# Processing Record 34 of Set 8 | muli
# Processing Record 35 of Set 8 | neyshabur
# Processing Record 36 of Set 8 | prince rupert
# Processing Record 37 of Set 8 | esperance
# Processing Record 38 of Set 8 | peniche
# Processing Record 39 of Set 8 | buyo
# Processing Record 40 of Set 8 | nawalgarh
# Processing Record 41 of Set 8 | norman
# Processing Record 42 of Set 8 | sinnamary
# Processing Record 43 of Set 8 | yulara
# Processing Record 44 of Set 8 | riyaq
# City not found. Skipping...
# Processing Record 45 of Set 8 | abha
# Processing Record 46 of Set 8 | rawson
# Processing Record 47 of Set 8 | verkhoyansk
# Processing Record 48 of Set 8 | kirensk
# Processing Record 49 of Set 8 | kimbe
# Processing Record 50 of Set 8 | bengkulu
# Processing Record 1 of Set 9 | nikolskoye
# Processing Record 2 of Set 9 | ouadda
# Processing Record 3 of Set 9 | sokoni
# Processing Record 4 of Set 9 | lompoc
# Processing Record 5 of Set 9 | alzamay
# Processing Record 6 of Set 9 | neuquen
# Processing Record 7 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 8 of Set 9 | west wendover
# Processing Record 9 of Set 9 | honningsvag
# Processing Record 10 of Set 9 | kargala
# Processing Record 11 of Set 9 | henderson
# Processing Record 12 of Set 9 | tra vinh
# Processing Record 13 of Set 9 | yakeshi
# Processing Record 14 of Set 9 | ilorin
# Processing Record 15 of Set 9 | port shepstone
# Processing Record 16 of Set 9 | bubaque
# Processing Record 17 of Set 9 | cozumel
# Processing Record 18 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 19 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 20 of Set 9 | srivardhan
# Processing Record 21 of Set 9 | gondar
# Processing Record 22 of Set 9 | asilah
# Processing Record 23 of Set 9 | shaunavon
# Processing Record 24 of Set 9 | armacao dos buzios
# City not found. Skipping...
# Processing Record 25 of Set 9 | yumen
# Processing Record 26 of Set 9 | eirunepe
# Processing Record 27 of Set 9 | boa vista
# Processing Record 28 of Set 9 | odessa
# Processing Record 29 of Set 9 | huilong
# Processing Record 30 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 31 of Set 9 | nouadhibou
# Processing Record 32 of Set 9 | bargal
# City not found. Skipping...
# Processing Record 33 of Set 9 | grootfontein
# Processing Record 34 of Set 9 | ketchikan
# Processing Record 35 of Set 9 | pareora
# Processing Record 36 of Set 9 | ust-nera
# Processing Record 37 of Set 9 | cabra
# Processing Record 38 of Set 9 | kingsport
# Processing Record 39 of Set 9 | barreiras
# Processing Record 40 of Set 9 | peterhead
# Processing Record 41 of Set 9 | carutapera
# Processing Record 42 of Set 9 | lebu
# Processing Record 43 of Set 9 | coquimbo
# Processing Record 44 of Set 9 | camacha
# Processing Record 45 of Set 9 | surt
# Processing Record 46 of Set 9 | chalakudi
# Processing Record 47 of Set 9 | hajipur
# Processing Record 48 of Set 9 | manono
# Processing Record 49 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 50 of Set 9 | omsukchan
# Processing Record 1 of Set 10 | sept-iles
# Processing Record 2 of Set 10 | mayo
# Processing Record 3 of Set 10 | san quintin
# Processing Record 4 of Set 10 | kirakira
# Processing Record 5 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 6 of Set 10 | sibenik
# Processing Record 7 of Set 10 | marsh harbour
# Processing Record 8 of Set 10 | watsa
# Processing Record 9 of Set 10 | kaikalur
# Processing Record 10 of Set 10 | mahina
# Processing Record 11 of Set 10 | pottstown
# Processing Record 12 of Set 10 | katsuura
# Processing Record 13 of Set 10 | fort nelson
# Processing Record 14 of Set 10 | imbituba
# Processing Record 15 of Set 10 | port macquarie
# Processing Record 16 of Set 10 | senador jose porfirio
# Processing Record 17 of Set 10 | goundam
# Processing Record 18 of Set 10 | limanowa
# Processing Record 19 of Set 10 | kamenskoye
# City not found. Skipping...
# Processing Record 20 of Set 10 | klaksvik
# Processing Record 21 of Set 10 | tabora
# Processing Record 22 of Set 10 | matara
# Processing Record 23 of Set 10 | pacific grove
# Processing Record 24 of Set 10 | chibombo
# Processing Record 25 of Set 10 | glenwood springs
# Processing Record 26 of Set 10 | tselinnoye
# Processing Record 27 of Set 10 | acapulco
# Processing Record 28 of Set 10 | siparia
# Processing Record 29 of Set 10 | bozoum
# Processing Record 30 of Set 10 | sao francisco de paula
# Processing Record 31 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 32 of Set 10 | sri aman
# Processing Record 33 of Set 10 | ugoofaaru
# Processing Record 34 of Set 10 | san carlos de bariloche
# Processing Record 35 of Set 10 | shakawe
# Processing Record 36 of Set 10 | novosergiyevka
# Processing Record 37 of Set 10 | mikuni
# Processing Record 38 of Set 10 | ha giang
# Processing Record 39 of Set 10 | chernyshevskiy
# Processing Record 40 of Set 10 | bilibino
# Processing Record 41 of Set 10 | yerbogachen
# Processing Record 42 of Set 10 | katha
# City not found. Skipping...
# Processing Record 43 of Set 10 | nago
# Processing Record 44 of Set 10 | estepa
# Processing Record 45 of Set 10 | makakilo city
# Processing Record 46 of Set 10 | kudahuvadhoo
# Processing Record 47 of Set 10 | almeria
# Processing Record 48 of Set 10 | candawaga
# City not found. Skipping...
# Processing Record 49 of Set 10 | lingao
# Processing Record 50 of Set 10 | malanje
# Processing Record 1 of Set 11 | kasempa
# Processing Record 2 of Set 11 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 11 | mbour
# Processing Record 4 of Set 11 | aklavik
# Processing Record 5 of Set 11 | zeven
# Processing Record 6 of Set 11 | novaya igirma
# Processing Record 7 of Set 11 | thiruvananthapuram
# Processing Record 8 of Set 11 | grand river south east
# City not found. Skipping...
# Processing Record 9 of Set 11 | te anau
# Processing Record 10 of Set 11 | pauini
# Processing Record 11 of Set 11 | peruibe
# Processing Record 12 of Set 11 | guiren
# Processing Record 13 of Set 11 | opuwo
# Processing Record 14 of Set 11 | forio
# Processing Record 15 of Set 11 | carbonia
# Processing Record 16 of Set 11 | taoudenni
# Processing Record 17 of Set 11 | colesberg
# Processing Record 18 of Set 11 | faanui
# Processing Record 19 of Set 11 | valparaiso
# Processing Record 20 of Set 11 | aojiang
# Processing Record 21 of Set 11 | port-gentil
# Processing Record 22 of Set 11 | kutum
# Processing Record 23 of Set 11 | mayor pablo lagerenza
# Processing Record 24 of Set 11 | carballo
# Processing Record 25 of Set 11 | swellendam
# Processing Record 26 of Set 11 | kisangani
# Processing Record 27 of Set 11 | great yarmouth
# Processing Record 28 of Set 11 | tabory
# Processing Record 29 of Set 11 | goderich
# Processing Record 30 of Set 11 | ippy
# Processing Record 31 of Set 11 | mirpur bathoro
# City not found. Skipping...
# Processing Record 32 of Set 11 | colmenar viejo
# Processing Record 33 of Set 11 | moerai
# Processing Record 34 of Set 11 | tura
# Processing Record 35 of Set 11 | sembe
# Processing Record 36 of Set 11 | haines junction
# Processing Record 37 of Set 11 | atherton
# Processing Record 38 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 39 of Set 11 | los llanos de aridane
# Processing Record 40 of Set 11 | oxbow
# Processing Record 41 of Set 11 | florida
# Processing Record 42 of Set 11 | tautira
# Processing Record 43 of Set 11 | chontalpa
# Processing Record 44 of Set 11 | tongliao
# Processing Record 45 of Set 11 | gunjur
# Processing Record 46 of Set 11 | hirara
# Processing Record 47 of Set 11 | qui nhon
# Processing Record 48 of Set 11 | sturgeon bay
# Processing Record 49 of Set 11 | jalu
# Processing Record 50 of Set 11 | sidi ali
# Processing Record 1 of Set 12 | mahon
# Processing Record 2 of Set 12 | tomari
# Processing Record 3 of Set 12 | ambon
# Processing Record 4 of Set 12 | tilichiki
# Processing Record 5 of Set 12 | sabinopolis
# Processing Record 6 of Set 12 | eenhana
# Processing Record 7 of Set 12 | taltal
# Processing Record 8 of Set 12 | petropavl
# Processing Record 9 of Set 12 | musoma
# Processing Record 10 of Set 12 | mapiripan
# Processing Record 11 of Set 12 | toulepleu
# City not found. Skipping...
# Processing Record 12 of Set 12 | genhe
# Processing Record 13 of Set 12 | batticaloa
# Processing Record 14 of Set 12 | hami
# Processing Record 15 of Set 12 | quatre cocos
# Processing Record 16 of Set 12 | petukhovo
# Processing Record 17 of Set 12 | sumenep
# Processing Record 18 of Set 12 | gorontalo
# Processing Record 19 of Set 12 | hampton
# Processing Record 20 of Set 12 | lapeer
# Processing Record 21 of Set 12 | zermatt
# Processing Record 22 of Set 12 | warwick
# Processing Record 23 of Set 12 | longyan
# Processing Record 24 of Set 12 | celestun
# Processing Record 25 of Set 12 | kuching
# Processing Record 26 of Set 12 | choma
# Processing Record 27 of Set 12 | usinsk
# Processing Record 28 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 29 of Set 12 | natal
# Processing Record 30 of Set 12 | xining
# Processing Record 31 of Set 12 | ape
# Processing Record 32 of Set 12 | harper
# Processing Record 33 of Set 12 | ilulissat
# Processing Record 34 of Set 12 | kralendijk
# Processing Record 35 of Set 12 | riyadh
# Processing Record 36 of Set 12 | leh
# Processing Record 37 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 38 of Set 12 | adrar
# Processing Record 39 of Set 12 | inuvik
# Processing Record 40 of Set 12 | dehloran
# Processing Record 41 of Set 12 | mithi
# Processing Record 42 of Set 12 | nicoya
# Processing Record 43 of Set 12 | den helder
# Processing Record 44 of Set 12 | pouebo
# Processing Record 45 of Set 12 | katherine
# Processing Record 46 of Set 12 | katete
# Processing Record 47 of Set 12 | padang
# Processing Record 48 of Set 12 | auki
# Processing Record 49 of Set 12 | nizhniy baskunchak
# Processing Record 50 of Set 12 | jijiga
# Processing Record 1 of Set 13 | farafangana
# Processing Record 2 of Set 13 | black river
# Processing Record 3 of Set 13 | tabou
# Processing Record 4 of Set 13 | yar-sale
# Processing Record 5 of Set 13 | matamoros
# Processing Record 6 of Set 13 | khovu-aksy
# Processing Record 7 of Set 13 | havre-saint-pierre
# Processing Record 8 of Set 13 | doha
# Processing Record 9 of Set 13 | jocotitlan
# Processing Record 10 of Set 13 | presidencia roque saenz pena
# Processing Record 11 of Set 13 | bathsheba
# Processing Record 12 of Set 13 | ponnani
# Processing Record 13 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 14 of Set 13 | saquarema
# Processing Record 15 of Set 13 | westport
# Processing Record 16 of Set 13 | baie-comeau
# Processing Record 17 of Set 13 | raga
# Processing Record 18 of Set 13 | merzifon
# Processing Record 19 of Set 13 | faridan
# City not found. Skipping...
# Processing Record 20 of Set 13 | kieta
# Processing Record 21 of Set 13 | kindersley
# Processing Record 22 of Set 13 | nizwa
# Processing Record 23 of Set 13 | bilma
# Processing Record 24 of Set 13 | la gaulette
# City not found. Skipping...
# Processing Record 25 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 26 of Set 13 | bud
# Processing Record 27 of Set 13 | okemos
# Processing Record 28 of Set 13 | pochutla
# Processing Record 29 of Set 13 | zeljezno polje
# Processing Record 30 of Set 13 | karamay
# City not found. Skipping...
# Processing Record 31 of Set 13 | sao miguel do araguaia
# Processing Record 32 of Set 13 | shpykiv
# City not found. Skipping...
# Processing Record 33 of Set 13 | chippewa falls
# Processing Record 34 of Set 13 | karaul
# City not found. Skipping...
# Processing Record 35 of Set 13 | bara
# Processing Record 36 of Set 13 | igrim
# Processing Record 37 of Set 13 | soyo
# Processing Record 38 of Set 13 | turukhansk
# Processing Record 39 of Set 13 | alamos
# Processing Record 40 of Set 13 | rauma
# Processing Record 41 of Set 13 | isabela
# Processing Record 42 of Set 13 | tamandare
# Processing Record 43 of Set 13 | hualmay
# Processing Record 44 of Set 13 | north bend
# Processing Record 45 of Set 13 | hatillo
# Processing Record 46 of Set 13 | vaitape
# Processing Record 47 of Set 13 | ahipara
# Processing Record 48 of Set 13 | rio gallegos
# Processing Record 49 of Set 13 | lumeje
# Processing Record 50 of Set 13 | beidao
# Processing Record 1 of Set 14 | port lincoln
# Processing Record 2 of Set 14 | glasgow
# Processing Record 3 of Set 14 | yarim
# Processing Record 4 of Set 14 | verkhoturye
# Processing Record 5 of Set 14 | barra do garcas
# Processing Record 6 of Set 14 | mys shmidta
# City not found. Skipping...
# Processing Record 7 of Set 14 | praia da vitoria
# Processing Record 8 of Set 14 | half moon bay
# Processing Record 9 of Set 14 | olinda
# Processing Record 10 of Set 14 | essex
# Processing Record 11 of Set 14 | phan rang
# City not found. Skipping...
# Processing Record 12 of Set 14 | avera
# Processing Record 13 of Set 14 | namatanai
# Processing Record 14 of Set 14 | selfoss
# Processing Record 15 of Set 14 | lerwick
# Processing Record 16 of Set 14 | barawe
# City not found. Skipping...
# Processing Record 17 of Set 14 | clarence town
# Processing Record 18 of Set 14 | srednekolymsk
# Processing Record 19 of Set 14 | ngorongoro
# Processing Record 20 of Set 14 | gladstone
# Processing Record 21 of Set 14 | makubetsu
# Processing Record 22 of Set 14 | villa rica
# Processing Record 23 of Set 14 | salvador
# Processing Record 24 of Set 14 | vryburg
# Processing Record 25 of Set 14 | tayga
# Processing Record 26 of Set 14 | solano
# Processing Record 27 of Set 14 | kenai
# Processing Record 28 of Set 14 | sitka
# Processing Record 29 of Set 14 | mouzakion
# City not found. Skipping...
# Processing Record 30 of Set 14 | mattru
# Processing Record 31 of Set 14 | putina
# Processing Record 32 of Set 14 | nioro
# Processing Record 33 of Set 14 | lipin bor
# Processing Record 34 of Set 14 | saint-joseph
# Processing Record 35 of Set 14 | pavilosta
# Processing Record 36 of Set 14 | teluknaga
# Processing Record 37 of Set 14 | pangnirtung
# Processing Record 38 of Set 14 | kochi
# Processing Record 39 of Set 14 | san pedro de macoris
# Processing Record 40 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 41 of Set 14 | alekseyevsk
# Processing Record 42 of Set 14 | huarmey
# Processing Record 43 of Set 14 | hovd
# Processing Record 44 of Set 14 | bonavista
# Processing Record 45 of Set 14 | comodoro rivadavia
# Processing Record 46 of Set 14 | baran
# Processing Record 47 of Set 14 | sulphur
# Processing Record 48 of Set 14 | mackay
# Processing Record 49 of Set 14 | tenkodogo
# Processing Record 50 of Set 14 | nuuk
# Processing Record 1 of Set 15 | egvekinot
# Processing Record 2 of Set 15 | atar
# Processing Record 3 of Set 15 | whitefish
# Processing Record 4 of Set 15 | campbell river
# Processing Record 5 of Set 15 | ust-ilimsk
# Processing Record 6 of Set 15 | college
# Processing Record 7 of Set 15 | maine-soroa
# Processing Record 8 of Set 15 | batagay-alyta
# Processing Record 9 of Set 15 | viligili
# City not found. Skipping...
# Processing Record 10 of Set 15 | basco
# Processing Record 11 of Set 15 | akyab
# Processing Record 12 of Set 15 | hailey
# Processing Record 13 of Set 15 | labuhan
# Processing Record 14 of Set 15 | paita
# Processing Record 15 of Set 15 | pemba
# Processing Record 16 of Set 15 | neiafu
# Processing Record 17 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 18 of Set 15 | matagami
# Processing Record 19 of Set 15 | ulladulla
# Processing Record 20 of Set 15 | roros
# Processing Record 21 of Set 15 | strelka
# Processing Record 22 of Set 15 | ismailia
# Processing Record 23 of Set 15 | sibolga
# Processing Record 24 of Set 15 | namibe
# Processing Record 25 of Set 15 | kwinana
# Processing Record 26 of Set 15 | nikolsk
# Processing Record 27 of Set 15 | archidona
# Processing Record 28 of Set 15 | hay river
# Processing Record 29 of Set 15 | laela
# Processing Record 30 of Set 15 | santa cruz
# Processing Record 31 of Set 15 | puerto baquerizo moreno
# Processing Record 32 of Set 15 | ixtapa
# Processing Record 33 of Set 15 | tomatlan
# Processing Record 34 of Set 15 | tam ky
# Processing Record 35 of Set 15 | jacareacanga
# Processing Record 36 of Set 15 | breves
# Processing Record 37 of Set 15 | dawson creek
# Processing Record 38 of Set 15 | muros
# Processing Record 39 of Set 15 | dhidhdhoo
# Processing Record 40 of Set 15 | tacoronte
# Processing Record 41 of Set 15 | garm
# City not found. Skipping...
# Processing Record 42 of Set 15 | smoky lake
# Processing Record 43 of Set 15 | port hedland
# Processing Record 44 of Set 15 | viedma
# Processing Record 45 of Set 15 | emborion
# Processing Record 46 of Set 15 | tando muhammad khan
# Processing Record 47 of Set 15 | deputatskiy
# Processing Record 48 of Set 15 | red deer
# Processing Record 49 of Set 15 | bowen
# Processing Record 50 of Set 15 | kiyevskoye
# Processing Record 1 of Set 16 | anacortes
# Processing Record 2 of Set 16 | trincomalee
# Processing Record 3 of Set 16 | pestisani
# Processing Record 4 of Set 16 | cortez
# Processing Record 5 of Set 16 | sili
# Processing Record 6 of Set 16 | wattegama
# Processing Record 7 of Set 16 | leningradskiy
# Processing Record 8 of Set 16 | suzu
# City not found. Skipping...
# Processing Record 9 of Set 16 | urusha
# Processing Record 10 of Set 16 | saint-georges
# Processing Record 11 of Set 16 | touros
# Processing Record 12 of Set 16 | caruray
# Processing Record 13 of Set 16 | shahreza
# Processing Record 14 of Set 16 | high point
# Processing Record 15 of Set 16 | yanan
# City not found. Skipping...
# Processing Record 16 of Set 16 | japura
# Processing Record 17 of Set 16 | mabaruma
# Processing Record 18 of Set 16 | tambovka
# Processing Record 19 of Set 16 | asau
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Carnarvon -24.87  113.63     69.80        88           0       23.04
# 1         Kavieng  -2.57  150.80     82.35        77          84       10.94
# 2    Ponta Do Sol  32.67  -17.10     57.20        71          40       17.22
# 3       Singaraja  -8.11  115.09     80.11        78         100        7.09
# 4          Anadyr  64.75  177.48      6.80        84           0        8.95
# 5    Norman Wells  65.28 -126.83     10.40        72          75        5.82
# 6        Cururupu  -1.83  -44.87     90.05        52          95        9.35
# 7  Severo-Kurilsk  50.68  156.12     27.86        88          91       28.43
# 8            Hofn  64.25  -15.21     35.60        80          20       23.04
# 9         Iqaluit  63.75  -68.51     12.20        72          75       10.29
#
#   Country Current Description
# 0      AU           clear sky
# 1      PG          light rain
# 2      PT    scattered clouds
# 3      ID     overcast clouds
# 4      RU           clear sky
# 5      CA       broken clouds
# 6      BR     overcast clouds
# 7      RU     overcast clouds
# 8      IS          few clouds
# 9      CA          light snow

# %%
# Reorganize column order
new_column_order=['City','Country','Lat','Lng','Max Temp','Humidity','Cloudiness','Wind Speed','Current Description']
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0       Carnarvon      AU -24.87  113.63     69.80        88           0
# 1         Kavieng      PG  -2.57  150.80     82.35        77          84
# 2    Ponta Do Sol      PT  32.67  -17.10     57.20        71          40
# 3       Singaraja      ID  -8.11  115.09     80.11        78         100
# 4          Anadyr      RU  64.75  177.48      6.80        84           0
# 5    Norman Wells      CA  65.28 -126.83     10.40        72          75
# 6        Cururupu      BR  -1.83  -44.87     90.05        52          95
# 7  Severo-Kurilsk      RU  50.68  156.12     27.86        88          91
# 8            Hofn      IS  64.25  -15.21     35.60        80          20
# 9         Iqaluit      CA  63.75  -68.51     12.20        72          75
#
#    Wind Speed Current Description
# 0       23.04           clear sky
# 1       10.94          light rain
# 2       17.22    scattered clouds
# 3        7.09     overcast clouds
# 4        8.95           clear sky
# 5        5.82       broken clouds
# 6        9.35     overcast clouds
# 7       28.43     overcast clouds
# 8       23.04          few clouds
# 9       10.29          light snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
